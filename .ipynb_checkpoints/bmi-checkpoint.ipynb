# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
bmi_df = pd.read_csv('./bmi.csv')

# %%
bmi_df
# Out:
#    Sex   "Weight (lbs Sep)"   "Weight (lbs Apr)"   "BMI (Sep)"   "BMI (Apr)"
# 0    M                159.0                  130          0.00         18.14
# 1    M                214.0                  190         19.70         17.44
# 2    M                163.0                  152         24.09         22.43
# 3    M                205.0                  194         26.97         25.57
# 4    F                150.0                  141         21.51         20.10
# 5    M                130.0                  121         18.69         17.40
# 6    F                141.0                  132         24.24         22.88
# 7    F                  0.0                  117          0.00         20.23
# 8    F                154.0                  150         30.26         29.24
# 9    F                128.0                  123         21.88         21.02
# 10   F                110.0                  104         17.63         16.89
# ...

# %%
bmi_df.columns
# Out:
# Index(['Sex', ' "Weight (lbs Sep)"', ' "Weight (lbs Apr)"', ' "BMI (Sep)"',
#        ' "BMI (Apr)"'],
#       dtype='object')

# %%
bmi_df[' Weight (lbs Sep)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weight (lbs Sep)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-887c9e6f5489> in <module>()
# ...

# %%
pd.get_dummies(pd.Series(bmi_df['Sex'])).head()
# Out:
#    F  M
# 0  0  1
# 1  0  1
# 2  0  1
# 3  0  1
# 4  1  0
