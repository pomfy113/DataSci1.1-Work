# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
% matplotlib inline

# %%
titanic_df = pd.read_csv('./titanic.csv')

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dates = pd.date_range('20130101', periods=10)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06', '2013-01-07', '2013-01-08',
#                '2013-01-09', '2013-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
 2.5 * np.random.randn(2, 4) + 3
# Out:
# array([[ 1.58261466, -0.16464778,  5.48561342,  4.82719606],
#        [ 8.30579132, -1.60124119,  4.72908589,  2.83389515]])

# %%
 2.5 * np.random.randn(2, 4) + 3
# Out:
# array([[1.47428931, 6.94145527, 5.55288212, 2.14356378],
#        [3.314752  , 6.0192438 , 3.74457515, 0.27483224]])

# %%
10 * np.random.randn(2, 4)
# Out:
# array([[ -6.29945451,   7.63220407,  17.51808525,   0.85173167],
#        [-18.64047183,  -3.71288787, -16.77308527,  10.23568131]])

# %%
dates = pd.date_range('2015', periods=10)

# %%
dates
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(10,4), index=dates, columns=list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2015-01-01  0.816303 -1.057708  1.469539 -1.139252
# 2015-01-02 -1.441359  2.528977 -0.242545  0.289058
# 2015-01-03  0.571663  0.588217  0.849899  0.840325
# 2015-01-04 -0.357426 -0.265471 -0.536027  0.424060
# 2015-01-05  0.219011  0.936195 -1.304207 -0.914655
# 2015-01-06  0.552326  0.737800  0.241905 -0.817240
# 2015-01-07  0.218249  0.502978 -0.515467 -2.061405
# 2015-01-08 -2.208181  0.445749 -0.345802  1.108928
# 2015-01-09 -0.418569 -0.524324  1.088970 -0.908896
# 2015-01-10  1.164979  0.357440 -0.392860  0.177877

# %%
df
# Out:
#                    A         B         C         D
# 2015-01-01  0.816303 -1.057708  1.469539 -1.139252
# 2015-01-02 -1.441359  2.528977 -0.242545  0.289058
# 2015-01-03  0.571663  0.588217  0.849899  0.840325
# 2015-01-04 -0.357426 -0.265471 -0.536027  0.424060
# 2015-01-05  0.219011  0.936195 -1.304207 -0.914655
# 2015-01-06  0.552326  0.737800  0.241905 -0.817240
# 2015-01-07  0.218249  0.502978 -0.515467 -2.061405
# 2015-01-08 -2.208181  0.445749 -0.345802  1.108928
# 2015-01-09 -0.418569 -0.524324  1.088970 -0.908896
# 2015-01-10  1.164979  0.357440 -0.392860  0.177877

# %%
df.iloc[3][0]
# Out:
# -0.3574256639182505

# %%
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
titanic_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x="Embarked", palette="spring", data=titanic_df)

# %%
sns.barplot(x="Sex", y="Survived", palette="spring", data=titanic_df)

# %%
sns.regplot(x="Age", y="Fare", data=titanic_df)

# %%
sns.regplot(x="Age", y="Fare", scatter_kws={"s": titanic_df["SibSp"]}, data=titanic_df)
