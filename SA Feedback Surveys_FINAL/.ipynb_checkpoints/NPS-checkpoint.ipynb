# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # NPS Scores
# ## Summer Academy Data - 2016
# Let's start with grabbing information from 2016. It's simple, complete, and needs minimal cleaning.

# %%
csv_2017 = pd.read_csv('2017/Student Feedback Surveys-Superview.csv')

def clean_week(input):
    return int(input[-1])

def clean_rating(input):
    try:
        rating = int(input)
        return rating
    except ValueError:
        return False

csv_2017.columns = ['ID', 'Location', 'Track', 'Week', 'Rating', 'Pacing']
csv_2017 = csv_2017.drop(columns=['Pacing'])
csv_2017['Week'] = csv_2017['Week'].apply(clean_week)
csv_2017['Rating'] = csv_2017['Rating'].apply(clean_rating)
csv_2017.head()
# Out:
#     ID       Location           Track  Week Rating
# 0  134  San Francisco  Apps, Explorer     1      3
# 1   36    Los Angeles            Apps     1      4
# 2  117  San Francisco           Games     1      4
# 3  253            NaN             NaN     2      4
# 4  350  New York City  Apps, Explorer     1      4

# %% [markdown]
# ### Mean Ratings Per Week via Lineplot
#
# Below, we look for the average rating per week.

# %%
def find_means(data):
    points = []
    for i in range(1, 9):
        points.append(data[data["Week"] == i]["Rating"].mean())
    return np.array(points)

# %%
plt.plot(find_means(csv_2017))

# %% [markdown]
# ## Alt: Mean Ratings Per Week via Linear Regression
#
# Another route is using the regplot. With x-estimator, we can see the mean and standard deviation per week!

# %%
ax_rating = sns.regplot(x='Week', y='Rating', data=csv_2017, x_estimator=np.mean)

# %%
print(csv_2017[csv_2017["Week"] == 8]["Rating"].describe())
print(csv_2017[csv_2017["Week"] == 1]["Rating"].describe())
# Out:
# count      9
# unique     4
# top       10
# freq       4
# Name: Rating, dtype: int64
# count     288
# unique      8
# top         8
# freq       91
# Name: Rating, dtype: int64

# %% [markdown]
# ### NPS scores
# #### Converting NPS Scores
# Rather than using the mean, let's look at the NPS scores.
#
# NPS scores are an indicator as to whether someone will be a promoter (+1, score 9-10), passive (0, 7-8), or a detractor (-1, <7) of your product.

# %%
def nps_convert(input, max = 10):
    rating = input * (10 / max)
    if(rating <= 6):
        return -1
    elif(rating <= 8):
        return 0
    else:
        return 1

csv_2017['NPS'] = csv_2017['Rating'].apply(nps_convert)

# %%
ax_nps = sns.regplot(x='Week', y='NPS', data=csv_2017, x_estimator=np.mean)

# %% [markdown]
# ## Summer Academy Data - 2016
# Now, a little tougher; let's try to find a way to pull all the mesh of data together from the .csvs

# %%
import glob

week_csv = [[] for _ in range(7)]

def week_cleaner(data):
    # Renaming of columns
    rating_string = 'How would you rate your overall satisfaction with the Summer Academy this week?'
    pacing_string1 = 'How well are the tutorials paced?'
    pacing_string2 = 'How well is the schedule paced?'

    track_string = 'What track are you in?'
    rename = { rating_string:'Rating', pacing_string1:'Pacing', pacing_string2:'Pacing', track_string:'Track'}
    data = data.rename(columns=rename)

    # Keep track of week
    data['Week'] = i
    
    # Errant data
    if 'Unnamed: 0' in data.columns:
        data = data.drop(columns='Unnamed: 0')

    return data

for i in range(1, 8):
    weekly_csv_filenames = glob.glob('2016/Anon Week {}*.csv'.format(i))
    week_csv[i-1] = []
    

    for location in weekly_csv_filenames:
        data = pd.read_csv(location)
        week_csv[i-1].append(week_cleaner(data))
    
    week_csv[i-1] = pd.concat(week_csv[i-1], sort=True)
csv_2016 = pd.concat(week_csv)
display(csv_2016.head())
# Out:
#   Pacing Rating           Timestamp Track  Week
# 0      3      2  6/23/2016 22:24:53   NaN     1
# 1      3      2   6/27/2016 4:03:03   NaN     1
# 2      3      3  6/23/2016 22:13:04   NaN     1
# 3      4      4  6/23/2016 22:09:23   NaN     1
# 4      4      4  6/23/2016 22:11:39   NaN     1

# %%
csv_2016['Rating'] = csv_2016['Rating'].apply(clean_rating)
plt.plot(find_means(csv_2016))

# %%
csv_2016['NPS'] = csv_2016['Rating'].apply(nps_convert, max=5)
# Out:
# INPUT: 2 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: False MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 2 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 4 MAX: 5
# INPUT: 5 MAX: 5
# INPUT: 1 MAX: 5
# INPUT: 3 MAX: 5
# INPUT: 2 MAX: 5

# %%
ax_nps = sns.regplot(x='Week', y='NPS', data=csv_2016, x_estimator=np.mean)
