# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('./anime_cleaned.csv')

# %%
df = df.sort_values(by=['aired_from_year'])
plt.plot(df['aired_from_year'], df['score'])
df = df.set_index(['aired_from_year'])

# %%
df.sort_values(by=['aired_from_year'])
source = df['source'].value_counts()
fig = plt.figure()
ax = fig.add_subplot(111)

sns.barplot(x=source.values, y=source.index, orient="h")
# Out:
#       anime_id                      title             title_english  \
# 5917     23969        Fuku-chan no Kishuu                       NaN
# 6121     23971  Fuku-chan no Zousan Butai                       NaN
# 2428      3990              Kumo to Tulip  The Spider and the Tulip
# 1503      7523     Fuku-chan no Sensuikan                       NaN
# 6134      2765  Momotarou: Umi no Shinpei  Momotaro: Sacred Sailors
#
#      title_japanese                                     title_synonyms  \
# 5917       フクちゃんの奇襲                          Fuku-chan&#039;s Surprise
# 6121     フクちゃんの増産部隊  Fuku-chan&#039;s Troops, Fuku-chan&#039;s Prod...
# 2428      くもとちゅうりっぷ                                  Kumo to Chuurippu
# 1503    フクちゃん部隊出撃の歌                         Fuku-chan&#039;s Submarine
# 6134       桃太郎　海の神兵  Momotaro&#039;s Divine Sea Warriors, Momotarou...
#
#                                               image_url   type        source  \
# 5917  https://myanimelist.cdn-dena.com/images/anime/...  Movie         Other
# 6121                                                NaN  Movie         Other
# 2428  https://myanimelist.cdn-dena.com/images/anime/...  Movie  Picture book
# 1503  https://myanimelist.cdn-dena.com/images/anime/...  Movie         Other
# 6134  https://myanimelist.cdn-dena.com/images/anime/...  Movie      Original
#
#       episodes           status       ...         broadcast  \
# 5917         1  Finished Airing       ...               NaN
# 6121         1  Finished Airing       ...               NaN
# 2428         1  Finished Airing       ...               NaN
# 1503         1  Finished Airing       ...               NaN
# 6134         1  Finished Airing       ...               NaN
#
#                                                 related  \
# 5917  {'Other': [{'mal_id': 7523, 'type': 'anime', '...
# 6121  {'Other': [{'mal_id': 7523, 'type': 'anime', '...
# 2428                                                 []
# 1503  {'Other': [{'mal_id': 23969, 'type': 'anime', ...
# 6134  {'Prequel': [{'mal_id': 6857, 'type': 'anime',...
#
#                             producer    licensor  \
# 5917                             NaN         NaN
# 6121                             NaN         NaN
# 2428                        Shochiku  Funimation
# 1503                             NaN         NaN
# 6134  Shochiku, Ministry of the Navy  Funimation
#
#                                               studio  \
# 5917                    Shochiku Animation Institute
# 6121                    Shochiku Animation Institute
# 2428                    Shochiku Animation Institute
# 1503  Asahi Production, Shochiku Animation Institute
# 6134                    Shochiku Animation Institute
#
#                              genre  opening_theme  ending_theme  duration_min  \
# 5917            Comedy, Historical             []            []          11.0
# 6121            Comedy, Historical             []            []          11.0
# 2428                     Adventure             []            []          14.0
# 1503  Comedy, Military, Historical             []            []          30.0
# 6134              Action, Military             []            []          74.0
#
#       aired_from_year
# 5917           1942.0
# 6121           1943.0
# 2428           1943.0
# 1503           1944.0
# 6134           1945.0
#
# [5 rows x 33 columns]

# %%
ax = sns.lineplot(x="aired_from_year", y="score", hue="source", data=df)
# Out:
# ---------------------------------------------------------------------
# AttributeError                      Traceback (most recent call last)
# <ipython-input-62-288e0c9e7578> in <module>()
# ----> 1 ax = sns.lineplot(x="aired_from_year", y="score", hue="source", data=df)
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'
